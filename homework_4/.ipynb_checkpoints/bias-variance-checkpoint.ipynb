# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotib inline
import random
# Out:
# ERROR:root:Line magic function `%matplotib` not found.

# %%
def train(data):
    point1,point2 = random.sample(data,2)
    print(point1, point2)
    x1,y1 = point1
    x2,y2 = point2
        
    # for two points regression we have the equation
    # a = y_mean (x1+x2)/(x1^2 + x2^2)
    mean = (y1 + y2)/2.
    factor = (x1+x2)/(x1**2 + x2**2)
    
    return mean*factor
    
def target(point):
    return np.sign(np.sin(np.pi*point[0]))

def hypothesis(point):
    return np.sign(a*point[0])

def run(runs,data_size):
    for i in range(runs):
        training_data = []
        # create training_data
        for data_pt in range(data_size):
            x = random.uniform(-1,1)
            y = np.sin(np.pi*x)
            training_data.append([x,y])

        xp = [pt[0] for pt in training_data]
        yp = [pt[1] for pt in training_data]

        # plot the sine
        fig = plt.figure()
        ax = fig.add_subplot(111)
        plt.plot(xp,yp,',r' )
        ax.set_xlabel('$x_1$'), ax.set_ylabel('$x_2$')
        plt.savefig('plot.png', dpi=100)
        
        for j in range(data_size):
            a = []
            a.append(train(training_data))
            # print a few graphs to check 
        result = []
        for slope in a:
            a_p = random.choice(a)
            result.append(slope*(-1))
#             result.append()
                
        plt.plot(xp,yp,'b,',xp,yr,'r-')
        plt.savefig('plot' + str(i)+ '.png', dpi=100)
        yr = []
            
        # test for error count
        target_outputs = np.array([[target(pt)] for pt in training_data])
        g = np.mean(a)
        g_results = np.dot(training_data, g.T)
        
        return g

# %%
run(100,100)
# Out:
# [0.631205704525537, 0.9162437157871799] [-0.32795292451578595, -0.8574505653268513]
# [0.7726789273058723, 0.6549755108618726] [-0.16607279341406223, -0.498383380329163]
# [0.3139145644531456, 0.833930339785981] [0.12101923939117931, 0.371099837237823]
# [-0.0988452536117923, -0.3055647801322799] [-0.6944987087458656, -0.8190542511800503]
# [0.7726789273058723, 0.6549755108618726] [-0.43442118452126066, -0.9788524429666006]
# [0.6379822650195328, 0.9075078286644384] [0.0427685713863204, 0.13395752342098216]
# [0.9243262380152071, 0.23550304086700674] [-0.9464538052735134, -0.1674280683839896]
# [0.6115211304947767, 0.9392512804262164] [0.3051794464880604, 0.8184737453269175]
# [0.5041555857939484, 0.9999147826377479] [-0.5035377563133894, -0.9999382380344878]
# [0.8252378717018587, 0.5218612443036247] [-0.47283064153933885, -0.9963594681860735]
# [-0.5035377563133894, -0.9999382380344878] [0.9268915016691743, 0.22766313548925718]
# ...
